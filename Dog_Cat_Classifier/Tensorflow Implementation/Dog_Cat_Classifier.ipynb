# %%
import numpy as np 
import os
import pandas as pd
import random
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg

# %%
import tensorflow as tf 
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, Dense, BatchNormalization, Flatten, MaxPool2D, Dropout
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %%
random.seed(3)
tf.random.set_seed(3)

# %%
train_dir = './dogs-vs-cats/train'
test_dir = './dogs-vs-cats/test'

# %%
filenames = os.listdir(train_dir)
categories = []

for filename in filenames:
    category = filename.split('.')[0]
    if category == 'dog':
        categories.append(1)
    else:
        categories.append(0)

# %%
df = pd.DataFrame({'filename':filenames,
                    'category': categories})

# %%
df[:10]
# Out:
#         filename  category
# 0      cat.0.jpg         0
# 1      cat.1.jpg         0
# 2     cat.10.jpg         0
# 3    cat.100.jpg         0
# 4   cat.1000.jpg         0
# 5  cat.10000.jpg         0
# 6  cat.10001.jpg         0
# 7  cat.10002.jpg         0
# 8  cat.10003.jpg         0
# 9  cat.10004.jpg         0

# %%
df.head()
# Out:
#        filename  category
# 0     cat.0.jpg         0
# 1     cat.1.jpg         0
# 2    cat.10.jpg         0
# 3   cat.100.jpg         0
# 4  cat.1000.jpg         0

# %%
df.tail()
# Out:
#            filename  category
# 24995  dog.9995.jpg         1
# 24996  dog.9996.jpg         1
# 24997  dog.9997.jpg         1
# 24998  dog.9998.jpg         1
# 24999  dog.9999.jpg         1

# %%
df['category'].value_counts().plot.bar()

# %%
sample = random.choice(filenames)
image = mpimg.imread(train_dir + '/'+ sample)
plt.imshow(image)

# %%
df["category"] = df["category"].replace({0: 'cat', 1: 'dog'})

# %%
train_df, val_df = train_test_split(df, test_size = 0.2, random_state = 3)
train_df = train_df.reset_index(drop =True)
val_df = val_df.reset_index(drop =True)

# %%
train_datagen = ImageDataGenerator(rescale=1./255, shear_range= 0.1, zoom_range= 0.3, horizontal_flip=True)
val_datagen = ImageDataGenerator(rescale=1./255)

# %%
img_width = 128
img_height = 128
batch_size = 16

# %%
train_generator = train_datagen.flow_from_dataframe(train_df, 
                    train_dir, 
                    x_col='filename',
                    y_col='category',
                    target_size=(img_width, img_height),
                    class_mode='categorical',
                    batch_size= batch_size)
# Out:
# Found 20000 validated image filenames belonging to 2 classes.

# %%
val_generator = val_datagen.flow_from_dataframe(val_df, 
                    train_dir, 
                    x_col='filename',
                    y_col='category',
                    target_size=(img_width, img_height),
                    class_mode='categorical',
                    batch_size= batch_size)
# Out:
# Found 5000 validated image filenames belonging to 2 classes.

# %% [markdown]
# ## Build VGG16 Model

# %%
def plot_data(train_data, val_data, title):
    plt.plot(train_data)
    plt.plot(val_data)
    plt.legend(['Training_data','validation_data'])
    plt.title("Model " + str(title))
    plt.xlabel('Epoch')
    plt.ylabel(title)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=(3,3),kernel_initializer='he_uniform', input_shape = (img_width, img_height, 3)))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(filters=64, kernel_size=(5,5), kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Conv2D(filters=128, kernel_size=(5,5), kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2,2)))


model.add(Flatten())
model.add(Dense(512, activation='relu', kernel_initializer='he_uniform'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu', kernel_initializer='he_uniform'))
model.add(Dense(2, activation='softmax'))

# %%
optimizer = RMSprop(lr = 0.001)
model.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
#val_loss
early_stop = EarlyStopping(patience=10)
#val_accuracy
learning_rate_reduction =ReduceLROnPlateau(monitor='val_accuracy', patience=2,
                                            verbose = True , factor = 0.5, min_lr=0.00001)
callbacks = [early_stop, learning_rate_reduction]

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_22 (Conv2D)           (None, 126, 126, 32)      896
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 126, 126, 32)      128
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 59, 59, 64)        51264
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 59, 59, 64)        256
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 29, 29, 64)        0
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 29, 29, 64)        0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 25, 25, 128)       204928
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 25, 25, 128)       512
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 12, 12, 128)       0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dense_18 (Dense)             (None, 512)               9437696
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_20 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 9,728,642
# Trainable params: 9,728,194
# Non-trainable params: 448
# _________________________________________________________________

# %%
history = model.fit(train_generator, steps_per_epoch = len(train_generator), epochs = 50, validation_data = val_generator, validation_steps = len(val_generator), callbacks=callbacks)
# Out:
# Epoch 1/50
# 1250/1250 [==============================] - 81s 65ms/step - loss: 1.0455 - accuracy: 0.5457 - val_loss: 0.6523 - val_accuracy: 0.6280 - lr: 0.0010
# Epoch 2/50
# 1250/1250 [==============================] - 79s 64ms/step - loss: 0.7088 - accuracy: 0.6068 - val_loss: 0.6733 - val_accuracy: 0.6552 - lr: 0.0010
# Epoch 3/50
# 1250/1250 [==============================] - 79s 63ms/step - loss: 0.6884 - accuracy: 0.6459 - val_loss: 0.6205 - val_accuracy: 0.6674 - lr: 0.0010
# Epoch 4/50
# 1250/1250 [==============================] - 79s 64ms/step - loss: 0.6385 - accuracy: 0.6848 - val_loss: 0.5105 - val_accuracy: 0.7514 - lr: 0.0010
# Epoch 5/50
# 1250/1250 [==============================] - 80s 64ms/step - loss: 0.6106 - accuracy: 0.7035 - val_loss: 0.5697 - val_accuracy: 0.6962 - lr: 0.0010
# Epoch 6/50
# 1250/1250 [==============================] - 80s 64ms/step - loss: 0.5915 - accuracy: 0.7203 - val_loss: 0.5055 - val_accuracy: 0.7642 - lr: 0.0010
# Epoch 7/50
# 1250/1250 [==============================] - 80s 64ms/step - loss: 0.5767 - accuracy: 0.7334 - val_loss: 0.5137 - val_accuracy: 0.7716 - lr: 0.0010
# Epoch 8/50
# 1250/1250 [==============================] - 80s 64ms/step - loss: 0.5611 - accuracy: 0.7366 - val_loss: 0.7380 - val_accuracy: 0.7438 - lr: 0.0010
# Epoch 9/50
# 1250/1250 [==============================] - 80s 64ms/step - loss: 0.5474 - accuracy: 0.7460 - val_loss: 0.5470 - val_accuracy: 0.7782 - lr: 0.0010
# Epoch 10/50
# 1250/1250 [==============================] - 80s 64ms/step - loss: 0.5321 - accuracy: 0.7566 - val_loss: 0.5515 - val_accuracy: 0.7684 - lr: 0.0010
# Epoch 11/50
# 1250/1250 [==============================] - ETA: 0s - loss: 0.5319 - accuracy: 0.7603
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1250/1250 [==============================] - 81s 65ms/step - loss: 0.5319 - accuracy: 0.7603 - val_loss: 0.5696 - val_accuracy: 0.7292 - lr: 0.0010
# Epoch 12/50
# 1250/1250 [==============================] - 80s 64ms/step - loss: 0.4900 - accuracy: 0.7829 - val_loss: 0.4311 - val_accuracy: 0.8176 - lr: 5.0000e-04
# Epoch 13/50
# 1250/1250 [==============================] - 81s 65ms/step - loss: 0.4865 - accuracy: 0.7821 - val_loss: 0.4443 - val_accuracy: 0.8048 - lr: 5.0000e-04
# Epoch 14/50
# 1250/1250 [==============================] - ETA: 0s - loss: 0.4672 - accuracy: 0.7907
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1250/1250 [==============================] - 80s 64ms/step - loss: 0.4672 - accuracy: 0.7907 - val_loss: 0.4490 - val_accuracy: 0.8004 - lr: 5.0000e-04
# Epoch 15/50
# 1250/1250 [==============================] - 80s 64ms/step - loss: 0.4390 - accuracy: 0.8026 - val_loss: 0.5601 - val_accuracy: 0.7998 - lr: 2.5000e-04
# Epoch 16/50
# 1250/1250 [==============================] - 80s 64ms/step - loss: 0.4338 - accuracy: 0.8077 - val_loss: 0.4464 - val_accuracy: 0.8238 - lr: 2.5000e-04
# Epoch 17/50
# 1250/1250 [==============================] - 82s 65ms/step - loss: 0.4282 - accuracy: 0.8105 - val_loss: 0.3919 - val_accuracy: 0.8364 - lr: 2.5000e-04
# Epoch 18/50
# 1250/1250 [==============================] - 80s 64ms/step - loss: 0.4223 - accuracy: 0.8146 - val_loss: 0.4502 - val_accuracy: 0.8128 - lr: 2.5000e-04
# Epoch 19/50
# 1250/1250 [==============================] - ETA: 0s - loss: 0.4191 - accuracy: 0.8150
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1250/1250 [==============================] - 80s 64ms/step - loss: 0.4191 - accuracy: 0.8150 - val_loss: 0.4544 - val_accuracy: 0.8350 - lr: 2.5000e-04
# Epoch 20/50
# 1250/1250 [==============================] - 80s 64ms/step - loss: 0.4096 - accuracy: 0.8205 - val_loss: 0.3821 - val_accuracy: 0.8444 - lr: 1.2500e-04
# Epoch 21/50
# 1250/1250 [==============================] - 80s 64ms/step - loss: 0.4006 - accuracy: 0.8223 - val_loss: 0.3935 - val_accuracy: 0.8418 - lr: 1.2500e-04
# Epoch 22/50
# 1250/1250 [==============================] - ETA: 0s - loss: 0.3976 - accuracy: 0.8276
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 1250/1250 [==============================] - 79s 63ms/step - loss: 0.3976 - accuracy: 0.8276 - val_loss: 0.3842 - val_accuracy: 0.8388 - lr: 1.2500e-04
# Epoch 23/50
# 1250/1250 [==============================] - 80s 64ms/step - loss: 0.3859 - accuracy: 0.8295 - val_loss: 0.3895 - val_accuracy: 0.8396 - lr: 6.2500e-05
# Epoch 24/50
# 1250/1250 [==============================] - ETA: 0s - loss: 0.3842 - accuracy: 0.8311
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 1250/1250 [==============================] - 81s 65ms/step - loss: 0.3842 - accuracy: 0.8311 - val_loss: 0.4198 - val_accuracy: 0.8406 - lr: 6.2500e-05
# Epoch 25/50
# 1250/1250 [==============================] - 79s 63ms/step - loss: 0.3845 - accuracy: 0.8329 - val_loss: 0.3836 - val_accuracy: 0.8446 - lr: 3.1250e-05
# Epoch 26/50
# 1250/1250 [==============================] - 81s 64ms/step - loss: 0.3827 - accuracy: 0.8335 - val_loss: 0.3934 - val_accuracy: 0.8398 - lr: 3.1250e-05
# Epoch 27/50
# 1250/1250 [==============================] - ETA: 0s - loss: 0.3766 - accuracy: 0.8335
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 1250/1250 [==============================] - 80s 64ms/step - loss: 0.3766 - accuracy: 0.8335 - val_loss: 0.3996 - val_accuracy: 0.8398 - lr: 3.1250e-05
# Epoch 28/50
# 1250/1250 [==============================] - 81s 64ms/step - loss: 0.3789 - accuracy: 0.8318 - val_loss: 0.3779 - val_accuracy: 0.8422 - lr: 1.5625e-05
# Epoch 29/50
# 1250/1250 [==============================] - ETA: 0s - loss: 0.3769 - accuracy: 0.8342
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 1e-05.
# 1250/1250 [==============================] - 81s 65ms/step - loss: 0.3769 - accuracy: 0.8342 - val_loss: 0.3943 - val_accuracy: 0.8446 - lr: 1.5625e-05
# Epoch 30/50
# 1250/1250 [==============================] - 81s 64ms/step - loss: 0.3751 - accuracy: 0.8347 - val_loss: 0.3786 - val_accuracy: 0.8458 - lr: 1.0000e-05
# Epoch 31/50
# 1250/1250 [==============================] - 79s 63ms/step - loss: 0.3721 - accuracy: 0.8386 - val_loss: 0.3921 - val_accuracy: 0.8448 - lr: 1.0000e-05
# Epoch 32/50
# 1250/1250 [==============================] - 79s 63ms/step - loss: 0.3699 - accuracy: 0.8367 - val_loss: 0.3815 - val_accuracy: 0.8456 - lr: 1.0000e-05
# Epoch 33/50
# 1250/1250 [==============================] - 79s 63ms/step - loss: 0.3699 - accuracy: 0.8379 - val_loss: 0.3867 - val_accuracy: 0.8490 - lr: 1.0000e-05
# Epoch 34/50
# 1250/1250 [==============================] - 80s 64ms/step - loss: 0.3728 - accuracy: 0.8390 - val_loss: 0.3660 - val_accuracy: 0.8468 - lr: 1.0000e-05
# Epoch 35/50
# 1250/1250 [==============================] - 82s 65ms/step - loss: 0.3702 - accuracy: 0.8354 - val_loss: 0.3679 - val_accuracy: 0.8478 - lr: 1.0000e-05
# Epoch 36/50
# 1250/1250 [==============================] - 82s 65ms/step - loss: 0.3720 - accuracy: 0.8381 - val_loss: 0.3785 - val_accuracy: 0.8416 - lr: 1.0000e-05
# Epoch 37/50
# 1250/1250 [==============================] - 81s 65ms/step - loss: 0.3710 - accuracy: 0.8356 - val_loss: 0.3722 - val_accuracy: 0.8504 - lr: 1.0000e-05
# Epoch 38/50
# 1250/1250 [==============================] - 82s 66ms/step - loss: 0.3729 - accuracy: 0.8349 - val_loss: 0.3895 - val_accuracy: 0.8436 - lr: 1.0000e-05
# Epoch 39/50
# 1250/1250 [==============================] - 80s 64ms/step - loss: 0.3724 - accuracy: 0.8340 - val_loss: 0.3915 - val_accuracy: 0.8442 - lr: 1.0000e-05
# Epoch 40/50
# 1250/1250 [==============================] - 81s 65ms/step - loss: 0.3696 - accuracy: 0.8348 - val_loss: 0.3667 - val_accuracy: 0.8474 - lr: 1.0000e-05
# Epoch 41/50
# 1250/1250 [==============================] - 81s 65ms/step - loss: 0.3695 - accuracy: 0.8375 - val_loss: 0.3839 - val_accuracy: 0.8456 - lr: 1.0000e-05
# Epoch 42/50
# 1250/1250 [==============================] - 80s 64ms/step - loss: 0.3717 - accuracy: 0.8407 - val_loss: 0.3803 - val_accuracy: 0.8474 - lr: 1.0000e-05
# Epoch 43/50
# 1250/1250 [==============================] - 83s 66ms/step - loss: 0.3726 - accuracy: 0.8371 - val_loss: 0.3758 - val_accuracy: 0.8398 - lr: 1.0000e-05
# Epoch 44/50
# 1250/1250 [==============================] - 79s 63ms/step - loss: 0.3662 - accuracy: 0.8393 - val_loss: 0.3663 - val_accuracy: 0.8504 - lr: 1.0000e-05

# %%
plot_data(history.history['loss'], history.history['val_loss'], 'Loss')

# %%
plot_data(history.history['accuracy'], history.history['val_accuracy'], 'Accuracy')
